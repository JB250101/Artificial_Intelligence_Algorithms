# %% [markdown]
# ### Given Points:
# - **\( z_1 \)**: Close to point \( x \)
# - **\( z_2 \)**: Far away from point \( x \)
#
# ### Analyzing Each Option:
#
# #### Option (a):
# **\( k(z_1,x) \) will be close to 1 and \( k(z_2,x) \) will be close to 0.**
# - **\( k(z_1, x) \)**:
#   - Since \( z_1 \) is very close to \( x \), \( \|z_1 - x\|^2 \) is a small value.
#   - Thus, the term \( -\frac{\|z_1 - x\|^2}{2\sigma^2} \) will be a small negative number, making \( k(z_1, x) \) close to \( e^0 = 1 \).
#
# - **\( k(z_2, x) \)**:
#   - Since \( z_2 \) is far from \( x \), \( \|z_2 - x\|^2 \) is a large value.
#   - The term \( -\frac{\|z_2 - x\|^2}{2\sigma^2} \) will be a large negative number, resulting in \( k(z_2, x) \) approaching \( 0 \) (as \( e^{(\text{large negative value})} \) tends to vanish).
#
# - **Conclusion**: This option is **valid** because it accurately describes the behavior of the RBF kernel under the given conditions.
#
# ---
#
# #### Option (b):
# **\( k(z_1,x) \) will be close to 0 and \( k(z_2,x) \) will be close to 1.**
# - **\( k(z_1, x) \)**:
#   - This option incorrectly states that \( z_1 \) (which is close to \( x \)) would yield a kernel value close to 0. This is **not correct** because a small distance results in a kernel value close to 1.
#
# - **\( k(z_2, x) \)**:
#   - It incorrectly asserts that \( z_2 \) would give a kernel value close to 1 due to it being far from \( x \). This is also **not correct** since large distance results in a kernel value approaching 0.
#
# - **Conclusion**: This option is **invalid** due to the incorrect relationship between distance and kernel values.
#
# ---
#
# #### Option (c):
# **\( k(z_1,x) \) will be close to \( c_1, c_1 \gg 1 \), and \( k(z_2,x) \) will be close to \( c_2, c_2 \ll 0 \), where \( c_1, c_2 \in \mathbb{R} \)**
# - **\( k(z_1, x) \)**:
#   - While \( k(z_1, x) \) is correctly assessed to be close to a high value, the statement that \( c_1 \gg 1 \) is misleading. The value should be close to 1, not necessarily greater than 1 significantly.
#
# - **\( k(z_2, x) \)**:
#   - The assertion that \( c_2 \) would be a value less than 0 is incorrect because kernel values for the RBF kernel are always non-negative (since \( e^{\text{(something negative)}} \) is always positive).
#
# - **Conclusion**: This option is **invalid** due to the incorrect characterizations of \( k(z_1, x) \) being greater than 1 and \( k(z_2, x) \) being less than 0.
#
# ---
#
# #### Option (d):
# **\( k(z_1,x) \) will be close to \( c_1, c_1 \ll 0 \), and \( k(z_2,x) \) will be close to \( c_2, c_2 \gg 1 \), where \( c_1, c_2 \in \mathbb{R} \)**
# - **\( k(z_1, x) \)**:
#   - This option incorrectly implies that \( k(z_1, x) \) would approach a value less than 0. As previously discussed, the kernel outputs are always positive for the inputs, meaning \( k(z_1, x) \) should be close to 1, not a negative value.
#
# - **\( k(z_2, x) \)**:
#   - This asserts that \( k(z_2, x) \) would be a large value greater than 1, which again is incorrect. Kernel values for distances with substantial separation approach 0, not an excessively large value.
#
# - **Conclusion**: This option is **invalid** due to the incorrect definitions of both kernel values in relation to their distances.
#
# ---
#
# ### Final Summary:
# Through this detailed analysis, option **(a)** is the only correct choice, as it accurately represents the behavior of the Gaussian RBF kernel for points \( z_1 \) and \( z_2 \) at different distances from \( x \). Options **(b)**, **(c)**, and **(d)** each contain fundamental misunderstandings of how the kernel function behaves with respect to distance, leading to their invalidity.

# %% [markdown]
# Thank you for the clarification regarding the class points. Let's recalculate the weight vector, bias, and the equation of the decision boundary with the correct points.
#
# ### Given Points
# **Class -1 (denoted with plus, red)**:
# - Point A: (2, 3)
# - Point B: (1, 4)
#
# **Class +1 (denoted with triangles, blue)**:
# - Point C: (4, 5)
# - Point D: (5, 6)
#
# ### Step-by-Step Solution
#
# #### 1. Identify the Support Vectors
# For a linear SVM, the support vectors are the points closest to the decision boundary. In this case:
# - Support vectors from Class -1: (2, 3) and (1, 4)
# - Support vectors from Class +1: (4, 5) and (5, 6)
#
# ### 2. Formulate the Equations for Decision Boundary
# The decision boundary can be written in the form:
# \[
# \mathbf{w} \cdot \mathbf{x} + b = 0
# \]
# where \( \mathbf{w} = (w_1, w_2) \) corresponds to the weight vector, and \( b \) is the bias.
#
# ### 3. Finding the Weight Vector and Bias
# Using the support vectors, we have the following equations:
#
# For Class -1 (denoted as \(y = -1\)):
# 1. For Point A (2, 3):
#    \[
#    w_1(2) + w_2(3) + b = -1 \quad \text{(1)}
#    \]
# 2. For Point B (1, 4):
#    \[
#    w_1(1) + w_2(4) + b = -1 \quad \text{(2)}
#    \]
#
# For Class +1 (denoted as \(y = +1\)):
# 3. For Point C (4, 5):
#    \[
#    w_1(4) + w_2(5) + b = 1 \quad \text{(3)}
#    \]
# 4. For Point D (5, 6):
#    \[
#    w_1(5) + w_2(6) + b = 1 \quad \text{(4)}
#    \]
#
# ### Solve the Equations
# Now, we will solve these equations to find the weight vector \( \mathbf{w} \) and bias \( b \).
#
# **Step 1: Subtract equations (1) and (2)**
#
# Subtracting equation (1) from equation (2):
# \[
# (w_1(1) + w_2(4) + b) - (w_1(2) + w_2(3) + b) = 0
# \]
# This simplifies to:
# \[
# w_1(1 - 2) + w_2(4 - 3) = 0 \implies -w_1 + w_2 = 0 \implies w_2 = w_1 \quad \text{(5)}
# \]
#
# **Step 2: Substitute \( w_2 = w_1 \) into (1) and (3)**
# - Plug \( w_2 = w_1 \) into equation (1):
#    \[
#    w_1(2) + w_1(3) + b = -1 \implies 5w_1 + b = -1 \quad \text{(6)}
#    \]
#
# - Substitute into equation (3):
#    \[
#    4w_1 + 5w_1 + b = 1 \implies 9w_1 + b = 1 \quad \text{(7)}
#    \]
#
# **Step 3: Solve Equations (6) and (7)**
# Now we can subtract equation (6) from (7):
# \[
# (9w_1 + b) - (5w_1 + b) = 1 - (-1)
# \]
# This simplifies to:
# \[
# 4w_1 = 2 \implies w_1 = \frac{1}{2}
# \]
#
# **Step 4: Find \( w_2 \) and \( b \)**
# From equation (5):
# \[
# w_2 = \frac{1}{2}
# \]
#
# Now substitute \( w_1 \) back into equation (6) to find \( b \):
# \[
# 5\left(\frac{1}{2}\right) + b = -1 \implies \frac{5}{2} + b = -1 \implies b = -1 - \frac{5}{2} = -\frac{7}{2}
# \]
#
# ### Final Parameters
# - Weight vector \( \mathbf{w} = \left(\frac{1}{2}, \frac{1}{2}\right) \)
# - Bias \( b = -\frac{7}{2} \)
#
# ### Decision Boundary Equation
# The equation of the decision boundary is:
# \[
# \frac{1}{2}x_1 + \frac{1}{2}x_2 - \frac{7}{2} = 0
# \]
#
# ### (b) Support Vectors and Decision Boundary
#
# **Circle the Support Vectors:**
# - Points (2, 3), (1, 4), (4, 5), and (5, 6) should be circled as they are all considered support vectors.
#
# **Draw the Decision Boundary:**
# - The decision boundary can be rearranged as:
# \[
# x_1 + x_2 = 7 \quad (after multiplying by 2 to avoid fractions)
# \]
# This equation represents a line in the coordinate space that will separate the two classes.
#
# ### Visual Representation
# You should:
# - Circle the points (2, 3), (1, 4), (4, 5), and (5, 6).
# - Draw the line representing the decision boundary given by \( x_1 + x_2 = 7 \).
#
# ### Conclusion
# - **Weight Vector**: \( \mathbf{w} = \left(\frac{1}{2}, \frac{1}{2}\right) \)
# - **Bias**: \( b = -\frac{7}{2} \)
# - **Decision Boundary Equation**: \( x_1 + x_2 = 7 \)
#
# This detailed solution should give you a clear understanding of how to compute the weight vector, bias, and decision boundary for a linear SVM using the corrected dataset.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC

# %%
# Data points
X = np.array([[2, 3], [1, 4], [4, 5], [5, 6]])
# Classes
y = np.array([1, 1, -1, -1]) # -1 for class (-1) and 1 for class (1)

# %%
# Create SVM model
model = SVC(kernel='linear', C=1.0)
model.fit(X, y)
# Out:
# SVC(kernel='linear')

# %%
# Get weights and bias
weights = model.coef_[0]
bias = model.intercept_[0]
print("Weights:", weights)
print("Bias:", bias)
# Out:
# Weights: [-0.5 -0.5]
# Bias: 3.499999999999999

# %%
# Plotting function
def plot_svc_decision_boundary(model, X, y):
    plt.scatter(X[:, 0], X[:, 1], c=y, s=30, cmap='coolwarm', label='Data points')
    
    # Plot support vectors
    plt.scatter(model.support_vectors_[:, 0], model.support_vectors_[:, 1],
                facecolors='none', edgecolors='k', s=100, label='Support Vectors', linewidth=2)

    # Create grid to plot
    xlim = np.linspace(X[:, 0].min() - 1, X[:, 0].max() + 1, 100)
    ylim = np.linspace(X[:, 0].min() - 1, X[:, 1].max() + 1, 100)
    xx, yy = np.meshgrid(xlim, ylim)
    
    # Get decision function
    Z = model.decision_function(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    
    # Plot decision boundary and margins
    plt.contour(xx, yy, Z, colors='k', levels=[0], alpha=0.5, linewidths=1, linestyles='solid', label='Decision Boundary')
    plt.contour(xx, yy, Z, colors='k', levels=[-1, 1], alpha=0.5, linestyles='dashed') # Margins

    plt.title('SVM Decision Boundary with Support Vectors')
    plt.xlabel('X1')
    plt.ylabel('X2')
    plt.legend()
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.grid()
    plt.show()

# Call the plot function
plot_svc_decision_boundary(model, X, y)
# Out:
# C:\Users\jaivb\AppData\Local\Temp\ipykernel_19204\1641623333.py:19: UserWarning: The following kwargs were not used by contour: 'label'
#   plt.contour(xx, yy, Z, colors='k', levels=[0], alpha=0.5, linewidths=1, linestyles='solid', label='Decision Boundary')
